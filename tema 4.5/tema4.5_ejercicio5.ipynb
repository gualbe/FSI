# %%
import pandas as pd

# %%
df = pd.read_excel("3989.xlsx", header=7, nrows=53)
df.head()
# Out:
#                          2019T4   2019T3  ...  2002T3.4  2002T2.4  2002T1.4
# 0       Total Nacional  23158.8  23088.7  ...    1871.0    1861.7    1838.6
# 1          02 Albacete    180.9    182.6  ...      13.3      13.1      11.9
# 2  03 Alicante/Alacant    934.1    920.3  ...      69.2      70.5      64.3
# 3           04 Almería    352.1    334.3  ...      27.0      23.6      22.3
# 4       01 Araba/Álava    154.1    156.1  ...      13.4      14.5      14.0
#
# [5 rows x 361 columns]

# %% [markdown]
# ### Promedio de población activa a 2019 (trimestre 4) entre las diferentes provincias

# %%
df['2019T4'][1:].mean()
# Out:
# 445.3576923076922
